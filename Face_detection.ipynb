# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAJ-C/Face-detection/blob/main/Face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# 1. Load Haar Cascade classifier
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# 2. Load input image
image = cv2.imread("/content/group-happy-multiethnic-boys-smiling-camera-school-outdoor_442523-969.avif")  # change image name if needed

# Check if image loaded properly
if image is None:
    print("Error: Image not found")
    exit()

# 3. Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 4. Detect faces
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

# 5. Draw bounding boxes around faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# 6. Display total face count
print(f"Number of faces detected: {len(faces)}")

# 7. Show output image
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of faces detected: 5
# <PIL.Image.Image image mode=RGB size=626x392>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
